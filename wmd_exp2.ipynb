# %% [markdown]
# ## [Word2vec](https://code.google.com/archive/p/word2vec/) model
# Download here : https://drive.google.com/file/d/0B7XkCwpI5KDYNlNUTTlSS21pQmM/edit

# %%
# Loading the model with gensim
from gensim.models import KeyedVectors
import pandas as pd
import os

MODEL_PATH = '/home/b/Downloads/GoogleNews-vectors-negative300.bin.gz'

if not os.path.exists(MODEL_PATH):
    raise ValueError("SKIP: You need to download the google news model")
    
model = KeyedVectors.load_word2vec_format(MODEL_PATH, binary=True,limit=200000)

# %%
from nltk.corpus import stopwords
from nltk import wordpunct_tokenize

plus = {'hdfc'}
minus = {'what','how','where','when','why'}
stop = set(stopwords.words('english'))

stop.update(plus)
stop.difference_update(minus)

def get_tokens(sent):
    return [x for x in wordpunct_tokenize(sent.lower()) if x.isalnum() and x not in stop]

# %%
sentence_obama = 'Obama speaks to the media in Illinois'
sentence_obama_past = 'In Illinois, Obama spoke to journalists'
sentence_president = 'The president greets the press in Chicago'
sentence_arbitrary = 'Mary had a little lamb'

tokens_obama = get_tokens(sentence_obama)
tokens_president = get_tokens(sentence_president)
tokens_obama_past = get_tokens(sentence_obama_past)
tokens_arbitrary = get_tokens(sentence_arbitrary)

print ("'"+sentence_obama+"' vs. '"+sentence_obama+"' \t\t:",model.wmdistance(tokens_obama, tokens_obama))
print ("'"+sentence_obama+"' vs. '"+sentence_obama_past+"' \t\t:",model.wmdistance(tokens_obama, tokens_obama_past))
print ("'"+sentence_obama+"' vs. '"+sentence_president+"' \t:",model.wmdistance(tokens_obama, tokens_president))
print ("'"+sentence_obama+"' vs. '"+sentence_arbitrary+"' \t\t\t\t:",model.wmdistance(tokens_obama, tokens_arbitrary))
# Out:
# 'Obama speaks to the media in Illinois' vs. 'Obama speaks to the media in Illinois' 		: 0.0
# 'Obama speaks to the media in Illinois' vs. 'In Illinois, Obama spoke to journalists' 		: 1.751374609270841
# 'Obama speaks to the media in Illinois' vs. 'The president greets the press in Chicago' 	: 3.3901614766891077
# 'Obama speaks to the media in Illinois' vs. 'Mary had a little lamb' 				: 4.176404432301822

# %% [markdown]
# ## Loading the dataset

# %%
df = pd.read_excel('hdfc.xlsx')
df = df.drop_duplicates('Question')
df = df.reset_index()

qlabels = df['Question'].to_dict()

drop_list = []
for x in qlabels:
    for w in get_tokens(qlabels[x]):
        if w not in model.vocab:
            drop_list.append(x)

reduced = df.drop(drop_list)

qlabels = reduced['Question'].to_dict()
alabels = reduced['Answer'].to_dict()
reduced
# Out:
#      index                                           Question  \
# 1        1                  How can I repay my Personal Loan?
# 2        2  Are there any additional charges for loan repa...
# 3        3                                 What is Guarantor?
# 4        4                                 What is De-pledge?
# 5        5  Whom do I contact in case of ay further querie...
# 6        6      What is the minimum loan value/product value?
# 7        7  What are the tenures for which I can avail thi...
# 8        8  Which all locations HDFC Bank Consumer Durable...
# 9        9  How can I get my address changed in my loan ac...
# 13      13                      How do I utilize this amount?
# 14      14      What is the amount I can get as an overdraft?
# 15      15  What are the benefits of having a Current/Savi...
# 16      16    How much loan can I avail of for Professionals?
# 17      17              How do I repay my Professionals loan?
# 18      18  What security do I need to provide to obtain P...
# 19      19  What are the loan tenure options for Professio...
# 20      20     Are my property documents safe with HDFC Ltd.?
# 22      22  Do I have the option to structure my loan as p...
# 23      23     How will HDFC decide my home loan eligibility?
# 25      25  What are the benefits of having a Current/Savi...
# 26      26        How much loan can I avail of Business Loan?
# 27      27                   How do I repay my Business Loan?
# 28      28  What security do I need to provide to obtain a...
# 29      29  What are the loan tenure options for Business ...
# 30      30  How can I make a request to foreclose my Loan ...
# 31      31  What are the charges I need to pay to foreclos...
# 32      32  How do I apply for a Loan Against Property (LAP)?
# 33      33  What Property can be considered as collateral ...
# 34      34  What is the maximum loan I can get against my ...
# 35      35                How should the gold loan be repaid?
# ..     ...                                                ...
# 943    985  How can I close my Online Mutual Fund Account ...
# 944    986  Why do I need to give my income details? How c...
# 946    988  If I change my address/Bank account /Nominatio...
# 948    990            How do I buy Mutual Funds over the Net?
# 949    991  How can I use Mobile Banking to manage my Mutu...
# 951    993               What about a Minor becoming a Major?
# 952    994               How can I "Buy"/"Sell" Mutual Funds?
# 953    995  How can I change the default Bank Account that...
# 954    996  What is the procedure to close my Investment S...
# 955    997            How much am I charged for this service?
# 956    998                        Can I cancel a transaction?
# 959   1001  Can I sell/redeem schemes bought offline throu...
# 960   1002             How do I buy Mutual Fund over the Net?
# 962   1004  When will I be able to view the unit holdings ...
# 965   1007  Will I get an online confirmation of my transa...
# 966   1008  Who can be the first applicant in the Investme...
# 968   1010             What if I have already obtained a MIN?
# 969   1011       Who can open an Investment Services account?
# 970   1012       What are the advantages of investing in SIP?
# 973   1015   What are the schemes available to the customers?
# 974   1016  Do I need to inform about my change of Income ...
# 976   1018  How do I convert my existing portfolio of Mutu...
# 981   1023  I do not have an account with HDFC Bank, but w...
# 982   1024  Who do I inform about change of name/address/s...
# 983   1025    Is a nomination facility available for lockers?
# 984   1026        What are the timings for locker operations?
# 985   1027  How many nominees can be added to a single loc...
# 986   1028  Can I pay for the rent of a locker through my ...
# 987   1029  What is the procedure to add / cancel / modify...
# 992   1034  Who should I contact for my replacement Card? ...
#
#                                                 Answer
# 1    You pay the loan in equal monthly instalments ...
# 2    The additional charges (if any) are applicable...
# 3    A Guarantor is a person who guarantees to pay ...
# 4    Removal of a pledge from the security to regai...
# 5    You can apply online on the clicking on the be...
# 6    We are funding products with loan value above ...
# 7    HDFC Bank Consumer Durable Loan is available i...
# 8    Mumbai,\nDelhi,\nBangalore,\nChennai,\nPune,\n...
# 9    In order to change your address in our records...
# 13   This amount is made available in your Salary A...
# 14   Depending on your eligibility, the maximum amo...
# 15   You get preferred Processing Fee, priority pro...
# 16   You can avail of a loan from Rs 50,000/- to Rs...
# 17   You pay the loan in equal monthly instalments ...
# 18   To obtain the loan, there is absolutely no nee...
# 19   You can repay your loan over a period of 12 to...
# 20   HDFC offers in-house scrutiny of property docu...
# 22   Yes, you can structure your HDFC Ltd.  Home Lo...
# 23   HDFC assess the customer's repayment capacity ...
# 25   You get preferred Processing Fee, priority pro...
# 26   You can avail of a loan from Rs 50,000/- to Rs...
# 27   You pay the loan in equal monthly instalments ...
# 28   To obtain the loan, there is absolutely no nee...
# 29   You can repay your loan over a period of 12 to...
# 30   Kindly submit a written request to your neares...
# 31   You may refer to the "Fees & Charges" option u...
# 32   You can apply for a loan in the following ways...
# 33   You can provide your self-occupied Residential...
# 34   You can get a Loan Against Property up to a ma...
# 35   The best thing about Loan against Gold is that...
# ..                                                 ...
# 943  To close your Online Mutual Fund account as we...
# 944  As per PMLA, it is mandatory for Mutual Funds ...
# 946  For all changes in account profile, or bank ac...
# 948  To invest through NetBanking log onto www.hdfc...
# 949  We request you to follow the steps mentioned b...
# 951  When a minor attaining majority ( completes 18...
# 952  Once you are registered for an Investment Serv...
# 953  We understand that you wish to change the Bank...
# 954  You will need to submit the Investment Service...
# 955  A quarterly maintenance charge is applicable t...
# 956  No cancellations are allowed once transactions...
# 959  No, only those schemes bought through the onli...
# 960  To invest through NetBanking Log onto\nwww.hdf...
# 962  The unit holdings will be reflected within T+2...
# 965  An order once placed will be confirmed immedia...
# 966  The first applicant of the Mutual Fund Investm...
# 968  Scenario 1\nIf the MIN was obtained by submitt...
# 969  Any Individual or HUF, who has an HDFC Bank Sa...
# 970  A large part of the success of Mutual Funds is...
# 973  Only select schemes of select AMC's are curren...
# 974  Yes. If you find an increased/decrease in your...
# 976         Currently, this facility is not available.
# 981  You can contact any HDFC bank Branch to open a...
# 982  You should intimate your change of name/addres...
# 983  Yes, a nomination facility is available to Ind...
# 984  You can plan your visit and access your locker...
# 985  A nomination can be made in favour of only one...
# 986  Yes, you can set a Standing Instruction in you...
# 987  You will need to fill up the following forms a...
# 992  You can contact HDFC Bank PhoneBanking number ...
#
# [606 rows x 3 columns]

# %% [markdown]
# ## Finding closest question using WmdSimilarity

# %%
from gensim.similarities import WmdSimilarity
questions = reduced['Question'].values

instance = WmdSimilarity([get_tokens(x) for x in questions], model, num_best=5)

# %%
def predict_wmd(sent):
    query = get_tokens(sent)
    sims = instance[query]
    scores = []
    for i in range(5):
        scores.append({"Score":'%.4f' % sims[i][1],"Question":questions[sims[i][0]]})
    return pd.DataFrame(scores)
predict('What is the procedure to pay my Personal Loan?')
# Out:
#                                             Question     Score
# 0                What is the cancellation procedure?  0.433564
# 1                  How can I repay my Personal Loan?  0.400332
# 2  What are the charges I need to pay to foreclos...  0.352948
# 3             Can I repay the Personal loan earlier?  0.334612
# 4  What is a Personal Assurance Message or Person...  0.331042

# %% [markdown]
# ## WMD Similarity vs. TF-IDF
# - WMD
#     - Uses word2vec to embed and commpare words.
#     - Hence distance between two words (which is used to compute distance between documents) reflects their real-life relationship
#     - Computationally expensive. `O(p^3*logp)` , where p is the size of the corpus
# - TF-IDF
#     - Doesn't reflect real-life relationships
#     - Importance/weight assigned to each word is inversely proportional to its frequency in the corpus
#     - Faster to compute than wmd since vocabulary is much smaller
#     - Cannot matches questions with synonyms

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk import FreqDist
import numpy as np

# Training tfidf vectoriser
tf_vect =TfidfVectorizer(stop_words=stop,
                         lowercase=True,
                         use_idf=True)
all_qs_vectors = tf_vect.fit_transform(questions)

all_words = wordpunct_tokenize(' '.join(questions).lower())
fdist = FreqDist(all_words)

# Function to predict closest question using TF-IDF
def predict(query,n=5,answers=False):
    query_vector = tf_vect.transform([query])
    arr = np.dot(all_qs_vectors, query_vector.T).toarray().flatten()
    matches,results = arr.argsort(axis=0)[::-1],[]
    for i in matches[:n]:
        res = {"Question":questions[i],"Score":arr[i]}
        results.append(res)
    return pd.DataFrame(results)

# %%
query = 'What is the procedure to pay my Personal Loan?'
word_dist = [{"word":w,"count":fdist[w]} for w in get_tokens(query)]
pd.DataFrame(word_dist).sort_values('count')
# Out:
#    count       word
# 1      7  procedure
# 2     20        pay
# 3     23   personal
# 4    103       loan
# 0    206       what

# %% [markdown]
# #### Consider the question : **What is the procedure to pay my Personal Loan?**
# - TFIDF suggests '*What is the cancellation procedure*' by matching the words **procedure** and **what**
#     - This is closely followed by '*How can I repay my Personal Loan?*' by matching the words **Personal** and **Loan**
#     - Thus, the word **procedure** is assigned greater importance simply due to lack of questions with **procedure**
#     - This worked to our benefit in the previous notebook where **Amortization** was assigned greater importance but backfires when common words aren't just as common/frequent in the corpus
#     - Hence, WMD performs a lot better than tfidf when we have a limited set of questions
# - WMD suggests '*How can I repay my Personal Loan?*' by roughly matching
#     - **What is the procedure** to **How**
#     - **pay** to **repay**

# %%
predict('What is the procedure to pay my Personal Loan?')
# Out:
#                                             Question     Score
# 0                What is the cancellation procedure?  0.433564
# 1                  How can I repay my Personal Loan?  0.400332
# 2  What are the charges I need to pay to foreclos...  0.352948
# 3             Can I repay the Personal loan earlier?  0.334612
# 4  What is a Personal Assurance Message or Person...  0.331042

# %%
predict_wmd('What is the procedure to pay my Personal Loan?')
# Out:
#                                             Question   Score
# 0                  How can I repay my Personal Loan?  0.6165
# 1  What are the charges I need to pay to foreclos...  0.6076
# 2  What are the charges I need to pay to foreclos...  0.5802
# 3             Can I repay the Personal loan earlier?  0.5799
# 4     How long can I take to repay my personal loan?  0.5783
